# %% [markdown]
# # typical experiments
#
# Some sort of metric to show variability between different model use cases? Any other stories to tell?
#
# E.g. mean melt rate:
#
# ![image.png](attachment:fe0c3083-6950-4c41-a796-22f57252bb50.png)
